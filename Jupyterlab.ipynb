# %% [markdown]
# # Holiday Preference
#
# ### here we will discuss your holiday preference

# %%
x = input("You are: ")

# %% [markdown]
# #### You!

# %%
from IPython import display
display.Image("https://cdn.icon-icons.com/icons2/1674/PNG/512/person_110935.png")

# %%
y = input("Describe your dream holiday as detailed as possible: ")

# %% [markdown]
# #### Your dream vacation

# %%
from IPython import display
display.Image("https://cdn.mos.cms.futurecdn.net/wtqqnkYDYi2ifsWZVW2MT4-1024-80.jpg")

# %% [markdown]
# - beach
# - relaxing
# - free drinks

# %% [markdown]
# [For a better understanding](https://www.youtube.com/watch?v=GoXMo61EK-8)
